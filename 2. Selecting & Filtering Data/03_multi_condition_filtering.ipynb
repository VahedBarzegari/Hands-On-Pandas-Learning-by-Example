# %% [markdown]
# # Multi-Condition Filtering in Pandas
#
# In this notebook, you'll learn how to:
# - Combine multiple filtering conditions
# - Use `.isin()` for category filtering
# - Filter text with `.str.contains()`
# - Handle missing (NaN) values during filtering

# %% [markdown]
# 🟦 1. Sample Dataset

# %%
import pandas as pd
import numpy as np

data = {
    "trip_id": [1, 2, 3, 4, 5, 6, 7],
    "route": ["10A", "20B", "10A", "30C", "20B", "10A", None],
    "delay_min": [2, 15, 5, 30, None, 8, 12],
    "driver_name": ["Ali", "Sara", "John", "Ali", "Sara", None, "Mike"]
}

df = pd.DataFrame(data)
df
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 1        2   20B       15.0        Sara
# 2        3   10A        5.0        John
# 3        4   30C       30.0         Ali
# 4        5   20B        NaN        Sara
# 5        6   10A        8.0        None
# 6        7  None       12.0        Mike

# %% [markdown]
# 🟦 2. Combining Multiple Conditions

# %%
# Trips on route 10A with delay less than 10 minutes
df[(df["route"] == "10A") & (df["delay_min"] < 10)]
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 2        3   10A        5.0        John
# 5        6   10A        8.0        None

# %%
df[(df["delay_min"] > 10) | (df["route"] == "30C")]
# Out:
#    trip_id route  delay_min driver_name
# 1        2   20B       15.0        Sara
# 3        4   30C       30.0         Ali
# 6        7  None       12.0        Mike

# %% [markdown]
# 🟦 3. Filtering with .isin()

# %%
# Select only selected routes
selected_routes = ["10A", "20B"]

df[df["route"].isin(selected_routes)]
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 1        2   20B       15.0        Sara
# 2        3   10A        5.0        John
# 4        5   20B        NaN        Sara
# 5        6   10A        8.0        None

# %% [markdown]
# 🟦 4. Filtering with .str.contains()
#
# Filter text columns using substring patterns.

# %%
# Routes containing "0"
df[df["route"].str.contains("0", na=False)]
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 1        2   20B       15.0        Sara
# 2        3   10A        5.0        John
# 3        4   30C       30.0         Ali
# 4        5   20B        NaN        Sara
# 5        6   10A        8.0        None

# %%
# Case Insensitive Search
df[df["driver_name"].str.contains("ali", case=False, na=False)]
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 3        4   30C       30.0         Ali

# %% [markdown]
# 🟦 5. Handling NaN Values During Filtering

# %% [markdown]
# 5.1 Problematic Filtering

# %%
# This can break without na=False
df[df["route"].str.contains("A")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # This can break without na=False
# ----> 2 df[df["route"].str.contains("A")]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4103, in DataFrame.__getitem__(self, key)
#    4100     return self.where(key)
#    4102 # Do we have a (boolean) 1d indexer?
# -> 4103 if com.is_bool_indexer(key):
#    4104     return self._getitem_bool_array(key)
#    4106 # We are left with two options: a single key, and a collection of keys,
#    4107 # We interpret tuples as collections only for non-MultiIndex
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
#     135         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136         raise ValueError(na_msg)
#     137     return False
#     138 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# 5.2 Safe Filtering with NaN Handling

# %%
df[df["route"].str.contains("A", na=False)]
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 2        3   10A        5.0        John
# 5        6   10A        8.0        None

# %% [markdown]
# 5.3 Detecting Missing Values

# %%
df[df["delay_min"].isna()]
# Out:
#    trip_id route  delay_min driver_name
# 4        5   20B        NaN        Sara

# %% [markdown]
# 5.4 Filtering Non-NaN Rows

# %%
df[df["delay_min"].notna() & df["route"].notna()]
# Out:
#    trip_id route  delay_min driver_name
# 0        1   10A        2.0         Ali
# 1        2   20B       15.0        Sara
# 2        3   10A        5.0        John
# 3        4   30C       30.0         Ali
# 5        6   10A        8.0        None

# %% [markdown]
# 5.5 Combine Filtering + NaN Handling

# %%
df[
    (df["delay_min"].notna()) &
    (df["delay_min"] > 5) &
    (df["route"].isin(["10A", "30C"]))
]
# Out:
#    trip_id route  delay_min driver_name
# 3        4   30C       30.0         Ali
# 5        6   10A        8.0        None

# %% [markdown]
# # Advanced Examples
#
# 🟦 6. Using .query() for Cleaner Syntax

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank"],
    "age": [22, 35, 40, 28, 19, np.nan],
    "salary": [50000, 80000, 120000, 65000, 30000, 70000],
    "city": ["Toronto", "Toronto", "Montreal", "Vancouver", "Toronto", "Montreal"],
    "department": ["IT", "HR", "IT", "Finance", "HR", "IT"]
})

df
# Out:
#       name   age  salary       city department
# 0    Alice  22.0   50000    Toronto         IT
# 1      Bob  35.0   80000    Toronto         HR
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance
# 4      Eva  19.0   30000    Toronto         HR
# 5    Frank   NaN   70000   Montreal         IT

# %%
df.query("age > 30")
# Out:
#       name   age  salary      city department
# 1      Bob  35.0   80000   Toronto         HR
# 2  Charlie  40.0  120000  Montreal         IT

# %%
df.query("age > 25 and salary < 100000")
# Out:
#     name   age  salary       city department
# 1    Bob  35.0   80000    Toronto         HR
# 3  David  28.0   65000  Vancouver    Finance

# %%
min_salary = 60000
df.query("salary >= @min_salary")
# Out:
#       name   age  salary       city department
# 1      Bob  35.0   80000    Toronto         HR
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance
# 5    Frank   NaN   70000   Montreal         IT

# %%
target_city = "Toronto"
df.query("city == @target_city")
# Out:
#     name   age  salary     city department
# 0  Alice  22.0   50000  Toronto         IT
# 1    Bob  35.0   80000  Toronto         HR
# 4    Eva  19.0   30000  Toronto         HR

# %%
df.query("city == 'Toronto' and salary > 40000")
# Out:
#     name   age  salary     city department
# 0  Alice  22.0   50000  Toronto         IT
# 1    Bob  35.0   80000  Toronto         HR

# %%
df.query("department == 'IT' or department == 'Finance'")
# Out:
#       name   age  salary       city department
# 0    Alice  22.0   50000    Toronto         IT
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance
# 5    Frank   NaN   70000   Montreal         IT

# %%
df.query("not city == 'Montreal'")
# Out:
#     name   age  salary       city department
# 0  Alice  22.0   50000    Toronto         IT
# 1    Bob  35.0   80000    Toronto         HR
# 3  David  28.0   65000  Vancouver    Finance
# 4    Eva  19.0   30000    Toronto         HR

# %%
df.query("city in ['Toronto', 'Vancouver']")
# Out:
#     name   age  salary       city department
# 0  Alice  22.0   50000    Toronto         IT
# 1    Bob  35.0   80000    Toronto         HR
# 3  David  28.0   65000  Vancouver    Finance
# 4    Eva  19.0   30000    Toronto         HR

# %%
cities = ["Montreal", "Toronto"]
df.query("city in @cities")
# Out:
#       name   age  salary      city department
# 0    Alice  22.0   50000   Toronto         IT
# 1      Bob  35.0   80000   Toronto         HR
# 2  Charlie  40.0  120000  Montreal         IT
# 4      Eva  19.0   30000   Toronto         HR
# 5    Frank   NaN   70000  Montreal         IT

# %%
df.query("name.str.contains('a')", engine="python")
# Out:
#       name   age  salary       city department
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance
# 4      Eva  19.0   30000    Toronto         HR
# 5    Frank   NaN   70000   Montreal         IT

# %%
df.query("name.str.startswith('A')", engine="python")
# Out:
#     name   age  salary     city department
# 0  Alice  22.0   50000  Toronto         IT

# %%
df.query("name.str.contains('A', case=False)", engine="python")
# Out:
#       name   age  salary       city department
# 0    Alice  22.0   50000    Toronto         IT
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance
# 4      Eva  19.0   30000    Toronto         HR
# 5    Frank   NaN   70000   Montreal         IT

# %%
df.query("age.notnull()", engine="python")
# Out:
#       name   age  salary       city department
# 0    Alice  22.0   50000    Toronto         IT
# 1      Bob  35.0   80000    Toronto         HR
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance
# 4      Eva  19.0   30000    Toronto         HR

# %%
df.query("25 <= age <= 40")
# Out:
#       name   age  salary       city department
# 1      Bob  35.0   80000    Toronto         HR
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance

# %%
condition = "age > 25 and salary > 60000 and city == 'Toronto'"
df.query(condition)
# Out:
#   name   age  salary     city department
# 1  Bob  35.0   80000  Toronto         HR

# %%
df.query("salary > age * 2000")
# Out:
#       name   age  salary       city department
# 0    Alice  22.0   50000    Toronto         IT
# 1      Bob  35.0   80000    Toronto         HR
# 2  Charlie  40.0  120000   Montreal         IT
# 3    David  28.0   65000  Vancouver    Finance

# %%
df.query(
    "department == 'IT' "
    "and city == 'Toronto' "
    "and salary > 40000 "
    "and age.notnull()",
    engine="python"
)
# Out:
#     name   age  salary     city department
# 0  Alice  22.0   50000  Toronto         IT
