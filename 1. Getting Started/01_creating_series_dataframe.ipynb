# %% [markdown]
# 📘 01 — Creating Series and DataFrames

# %% [markdown]
# 🟦 1. Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# 🟦 2. Creating a Series

# %% [markdown]
# 2.1 From a Python list

# %%
numbers = [10, 20, 30, 40, 50]
s = pd.Series(numbers)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# 2.2 Setting custom index labels

# %%
s2 = pd.Series(numbers, index=["a", "b", "c", "d", "e"])
s2
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# 2.3 From a dictionary

# %%
data = {"Math": 90, "Science": 85, "History": 88}
s3 = pd.Series(data)
s3
# Out:
# Math       90
# Science    85
# History    88
# dtype: int64

# %% [markdown]
# 🟦 3. Creating a DataFrame

# %% [markdown]
# 3.1 From a dictionary of lists

# %%
student_data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [24, 19, 22],
    "Grade": ["A", "B", "A"]
}

df1 = pd.DataFrame(student_data)
df1
# Out:
#       Name  Age Grade
# 0    Alice   24     A
# 1      Bob   19     B
# 2  Charlie   22     A

# %% [markdown]
# 3.2 From a list of dictionaries

# %%
records = [
    {"Name": "Alice", "Age": 24, "Grade": "A"},
    {"Name": "Bob", "Age": 19, "Grade": "B"},
    {"Name": "Charlie", "Age": 22, "Grade": "A"}
]

df2 = pd.DataFrame(records)
df2
# Out:
#       Name  Age Grade
# 0    Alice   24     A
# 1      Bob   19     B
# 2  Charlie   22     A

# %% [markdown]
# 3.3 From a list of lists + custom column names

# %%
rows = [
    [1, "Apple", 3.5],
    [2, "Banana", 2.0],
    [3, "Orange", 4.2]
]

df3 = pd.DataFrame(rows, columns=["ID", "Fruit", "Price"])
df3
# Out:
#    ID   Fruit  Price
# 0   1   Apple    3.5
# 1   2  Banana    2.0
# 2   3  Orange    4.2

# %% [markdown]
# 🟦 4. Creating DataFrame with Custom Index

# %%
df4 = pd.DataFrame(
    student_data,
    index=["student_1", "student_2", "student_3"]
)
df4
# Out:
#               Name  Age Grade
# student_1    Alice   24     A
# student_2      Bob   19     B
# student_3  Charlie   22     A

# %% [markdown]
# 🟦 5. Creating DataFrame from NumPy Array

# %%
import numpy as np

arr = np.array([[10, 20], [30, 40], [50, 60]])
df5 = pd.DataFrame(arr, columns=["Col1", "Col2"])
df5
# Out:
#    Col1  Col2
# 0    10    20
# 1    30    40
# 2    50    60

# %% [markdown]
# 🟦 6. Adding Columns After Creation

# %%
df1["Passed"] = df1["Grade"].apply(lambda g: g in ["A", "B"])
df1
# Out:
#       Name  Age Grade  Passed
# 0    Alice   24     A    True
# 1      Bob   19     B    True
# 2  Charlie   22     A    True

# %% [markdown]
# 🟦 7. Setting and Resetting Index

# %% [markdown]
# Set index

# %%
df6 = df1.set_index("Name")
df6
# Out:
#          Age Grade  Passed
# Name
# Alice     24     A    True
# Bob       19     B    True
# Charlie   22     A    True

# %% [markdown]
# Reset index

# %%
df6.reset_index()
# Out:
#       Name  Age Grade  Passed
# 0    Alice   24     A    True
# 1      Bob   19     B    True
# 2  Charlie   22     A    True

# %% [markdown]
# ## 🟦 8. Summary
#
# In this section, you learned how to:
#
# - ✔️ Create **Series** from lists and dictionaries
# - ✔️ Create **DataFrames** in multiple different ways
# - ✔️ Set a **custom index** for your DataFrame
# - ✔️ Add new columns to a DataFrame
# - ✔️ Perform **basic operations** to explore and modify data
#
# Great job! 🎉
# You're now ready to move to the next section.
