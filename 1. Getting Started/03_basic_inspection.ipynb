# %% [markdown]
# This section teaches how to quickly examine and explore your datasets using:
#
# - `head()` and `tail()`
# - `info()`
# - `describe()`
# - Shape and size
# - Column names
# - Data types
# - Extra advanced inspection tools
#
# These tools help you understand structure, quality, and completeness of your data.

# %% [markdown]
# 🟦 1. Prepare Sample DataFrame

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank"],
    "Age": [24, 19, 22, 28, 32, None],
    "Score": [88, 75, 90, 65, None, 72],
    "City": ["Toronto", "Montreal", "Vancouver", "Calgary", "Toronto", "Calgary"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Score       City
# 0    Alice  24.0   88.0    Toronto
# 1      Bob  19.0   75.0   Montreal
# 2  Charlie  22.0   90.0  Vancouver
# 3    David  28.0   65.0    Calgary
# 4      Eva  32.0    NaN    Toronto
# 5    Frank   NaN   72.0    Calgary

# %% [markdown]
# 🟦 2. head() and tail()
#
# `head()` and `tail()` help you preview the dataset quickly.

# %%
df.head()    # first 5 rows
# Out:
#       Name   Age  Score       City
# 0    Alice  24.0   88.0    Toronto
# 1      Bob  19.0   75.0   Montreal
# 2  Charlie  22.0   90.0  Vancouver
# 3    David  28.0   65.0    Calgary
# 4      Eva  32.0    NaN    Toronto

# %%
df.tail(3)   # last 3 rows
# Out:
#     Name   Age  Score     City
# 3  David  28.0   65.0  Calgary
# 4    Eva  32.0    NaN  Toronto
# 5  Frank   NaN   72.0  Calgary

# %% [markdown]
# 🟦 3. info() — DataFrame Summary
#
# `info()` shows:
# - number of rows
# - column names
# - non-null values
# - data types
# - memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     5 non-null      float64
#  2   Score   5 non-null      float64
#  3   City    6 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %% [markdown]
# 🟦 4. describe() — Descriptive Statistics
#
# `describe()` computes basic statistics for numeric columns.

# %%
df.describe()
# Out:
#             Age      Score
# count   5.00000   5.000000
# mean   25.00000  78.000000
# std     5.09902  10.700467
# min    19.00000  65.000000
# 25%    22.00000  72.000000
# 50%    24.00000  75.000000
# 75%    28.00000  88.000000
# max    32.00000  90.000000

# %%
df.describe(include="all")
# Out:
#          Name       Age      Score     City
# count       6   5.00000   5.000000        6
# unique      6       NaN        NaN        4
# top     Alice       NaN        NaN  Toronto
# freq        1       NaN        NaN        2
# mean      NaN  25.00000  78.000000      NaN
# std       NaN   5.09902  10.700467      NaN
# min       NaN  19.00000  65.000000      NaN
# 25%       NaN  22.00000  72.000000      NaN
# 50%       NaN  24.00000  75.000000      NaN
# 75%       NaN  28.00000  88.000000      NaN
# max       NaN  32.00000  90.000000      NaN

# %% [markdown]
# 🟦 5. Checking Shape and Size
#
# Useful to quickly understand dataset dimensions.

# %%
df.shape       # (rows, columns)
# Out:
# (6, 4)

# %%
df.size        # total number of elements
# Out:
# 24

# %%
df.ndim        # number of dimensions
# Out:
# 2

# %% [markdown]
# 🟦 6. Viewing Column Names

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Score', 'City'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# 🟦 7. Checking Data Types

# %%
df.dtypes
# Out:
# Name      object
# Age      float64
# Score    float64
# City      object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     2
# float64    2
# Name: count, dtype: int64

# %% [markdown]
# 🟦 8. Checking for Missing Values

# %%
df.isna().sum()
# Out:
# Name     0
# Age      1
# Score    1
# City     0
# dtype: int64

# %% [markdown]
# 🟦 9. Viewing Unique Values & Counts

# %%
df["City"].unique()
# Out:
# array(['Toronto', 'Montreal', 'Vancouver', 'Calgary'], dtype=object)

# %%
df["City"].value_counts()
# Out:
# City
# Toronto      2
# Calgary      2
# Montreal     1
# Vancouver    1
# Name: count, dtype: int64

# %% [markdown]
# 🟦 10. Basic Correlation Analysis (Advanced)

# %%
df.corr(numeric_only=True)
# Out:
#             Age     Score
# Age    1.000000 -0.425212
# Score -0.425212  1.000000

# %% [markdown]
# 🟦 11. Viewing Memory Usage

# %%
df.memory_usage(deep=True)
# Out:
# Index    132
# Name     322
# Age       48
# Score     48
# City     339
# dtype: int64

# %% [markdown]
# 🟦 12. Sampling Random Rows

# %%
df.sample(3)
# Out:
#     Name   Age  Score     City
# 0  Alice  24.0   88.0  Toronto
# 5  Frank   NaN   72.0  Calgary
# 4    Eva  32.0    NaN  Toronto

# %% [markdown]
# # Summary
#
#
# In this subsection, you learned how to inspect and understand your data using:
#
# ### 🔍 **Previewing**
# - `head()` and `tail()`
# - `sample()`
#
# ### 🧱 **Structure & Schema**
# - `info()`
# - `shape`, `size`, `ndim`
# - Column names and index
# - Data types (`dtypes`)
#
# ### 📊 **Statistics & Quality**
# - `describe()` (numeric + all columns)
# - Unique values & counts
# - Missing value detection (`isna().sum()`)
# - Correlations (`corr()`)
#
# ### 🗂 **Advanced Exploration**
# - Memory usage (`memory_usage`)
# - Dtype distribution (`dtypes.value_counts()`)
