# %% [markdown]
# 🟦 1. Import Libraries and DataSet

# %%
import pandas as pd

data = {
    "route_id": [10, 10, 10, 20, 20, 30, 30],
    "direction": [0, 0, 1, 0, 1, 0, 1],
    "delay_min": [2, 5, 0, 7, 3, 1, 4],
    "trip_id": [101, 102, 103, 104, 105, 106, 107]
}

df = pd.DataFrame(data)
df
# Out:
#    route_id  direction  delay_min  trip_id
# 0        10          0          2      101
# 1        10          0          5      102
# 2        10          1          0      103
# 3        20          0          7      104
# 4        20          1          3      105
# 5        30          0          1      106
# 6        30          1          4      107

# %% [markdown]
# 🟦 2. Grouping by a Single Column

# %%
df.groupby("route_id")

#(No calculation happens yet.)

# %% [markdown]
# 🟦 3. Basic Aggregations

# %%
df.groupby("route_id")["delay_min"].mean()
# Out:
# route_id
# 10    2.333333
# 20    5.000000
# 30    2.500000
# Name: delay_min, dtype: float64

# %%
df.groupby("route_id")["delay_min"].sum()
# Out:
# route_id
# 10     7
# 20    10
# 30     5
# Name: delay_min, dtype: int64

# %%
df.groupby("route_id")["delay_min"].count()
# Out:
# route_id
# 10    3
# 20    2
# 30    2
# Name: delay_min, dtype: int64

# %%
df.groupby("route_id")["delay_min"].min()
# Out:
# route_id
# 10    0
# 20    3
# 30    1
# Name: delay_min, dtype: int64

# %%
df.groupby("route_id")["delay_min"].max()
# Out:
# route_id
# 10    5
# 20    7
# 30    4
# Name: delay_min, dtype: int64

# %% [markdown]
# 🟦 4. Multiple Aggregations Using .agg()

# %%
df.groupby("route_id")["delay_min"].agg(
    ["mean", "sum", "count", "min", "max"]
)
# Out:
#               mean  sum  count  min  max
# route_id
# 10        2.333333    7      3    0    5
# 20        5.000000   10      2    3    7
# 30        2.500000    5      2    1    4

# %% [markdown]
# 🟦 5. Direct Aggregation vs .agg()

# %% [markdown]
# 5.1 Direct aggregation

# %%
df.groupby("route_id")["delay_min"].mean()
# Out:
# route_id
# 10    2.333333
# 20    5.000000
# 30    2.500000
# Name: delay_min, dtype: float64

# %% [markdown]
# 5.2 Using .agg()

# %%
df.groupby("route_id").agg({
    "delay_min": "mean"
})
# Out:
#           delay_min
# route_id
# 10         2.333333
# 20         5.000000
# 30         2.500000

# %% [markdown]
# 🟦 6. Resetting Index

# %%
result = df.groupby("route_id")["delay_min"].mean().reset_index()
result
# Out:
#    route_id  delay_min
# 0        10   2.333333
# 1        20   5.000000
# 2        30   2.500000

# %% [markdown]
# 🟦 7. Group By Multiple Columns

# %%
df.groupby(["route_id", "direction"])["trip_id"].count().reset_index(name="trip_count")
# Out:
#    route_id  direction  trip_count
# 0        10          0           2
# 1        10          1           1
# 2        20          0           1
# 3        20          1           1
# 4        30          0           1
# 5        30          1           1

# %% [markdown]
# 🟦 8. Full Example

# %%
summary = (
    df.groupby("route_id")
      .agg(
          avg_delay=("delay_min", "mean"),
          total_delay=("delay_min", "sum"),
          trip_count=("trip_id", "count")
      )
      .reset_index()
)

summary
# Out:
#    route_id  avg_delay  total_delay  trip_count
# 0        10   2.333333            7           3
# 1        20   5.000000           10           2
# 2        30   2.500000            5           2

# %% [markdown]
# ## ✅ Summary
#
# | Concept                   | Example                   |
# | ------------------------- | ------------------------- |
# | Group single column       | `df.groupby("route_id")`  |
# | Basic aggregation         | `.mean()`, `.sum()`       |
# | Multiple aggregations     | `.agg(["mean", "max"])`   |
# | Rename aggregated columns | `agg(avg=("col","mean"))` |
# | Reset index               | `.reset_index()`          |
