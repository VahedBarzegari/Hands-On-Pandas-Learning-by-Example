# %% [markdown]
# 🟦 1. Import Libraries & Create Sample Data

# %%
import pandas as pd
import numpy as np

# Sample dataset
df = pd.DataFrame({
    "City": ["Toronto", "Toronto", "Toronto", "Vancouver", "Vancouver", "Montreal"],
    "Month": ["Jan", "Jan", "Feb", "Jan", "Feb", "Feb"],
    "Sales": [120, 80, 150, 90, 50, 200],
    "Units": [10, 6, 12, 7, 5, 15]
})

df
# Out:
#         City Month  Sales  Units
# 0    Toronto   Jan    120     10
# 1    Toronto   Jan     80      6
# 2    Toronto   Feb    150     12
# 3  Vancouver   Jan     90      7
# 4  Vancouver   Feb     50      5
# 5   Montreal   Feb    200     15

# %% [markdown]
# 🟦 2. Basic Pivot Table (Single Aggregation)

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="City",
    aggfunc="sum"
)
# Out:
#            Sales
# City
# Montreal     200
# Toronto      350
# Vancouver    140

# %% [markdown]
# 🟦 3. Pivot Table with Multiple Aggregations

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="City",
    aggfunc=["sum", "mean", "count"]
)
# Out:
#             sum        mean count
#           Sales       Sales Sales
# City
# Montreal    200  200.000000     1
# Toronto     350  116.666667     3
# Vancouver   140   70.000000     2

# %% [markdown]
# 🟦 4. Pivot with Multiple Index and Column Levels

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="City",
    columns="Month",
    aggfunc="sum"
)
# Out:
# Month        Feb    Jan
# City
# Montreal   200.0    NaN
# Toronto    150.0  200.0
# Vancouver   50.0   90.0

# %% [markdown]
# 🟦 5. Pivot with Multiple Value Columns

# %%
pd.pivot_table(
    df,
    values=["Sales", "Units"],
    index="City",
    aggfunc="sum"
)
# Out:
#            Sales  Units
# City
# Montreal     200     15
# Toronto      350     28
# Vancouver    140     12

# %% [markdown]
# 🟦 6. Pivot Table with Multiple Aggregations per Column

# %%
pd.pivot_table(
    df,
    values=["Sales", "Units"],
    index="City",
    aggfunc={"Sales": ["sum", "mean"], "Units": ["sum", "mean"]}
)
# Out:
#                 Sales           Units
#                  mean  sum       mean sum
# City
# Montreal   200.000000  200  15.000000  15
# Toronto    116.666667  350   9.333333  28
# Vancouver   70.000000  140   6.000000  12

# %% [markdown]
# 🟦 7. Handling Missing Values with fill_value

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="City",
    columns="Month",
    aggfunc="sum",
    fill_value=0
)
# Out:
# Month      Feb  Jan
# City
# Montreal   200    0
# Toronto    150  200
# Vancouver   50   90

# %% [markdown]
# 🟦 8. Adding Margins (Row & Column Totals)

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="City",
    columns="Month",
    aggfunc="sum",
    margins=True,
    margins_name="Total"
)
# Out:
# Month        Feb    Jan  Total
# City
# Montreal   200.0    NaN    200
# Toronto    150.0  200.0    350
# Vancouver   50.0   90.0    140
# Total      400.0  290.0    690

# %% [markdown]
# 🟦 9. Pivot Table with Custom Function

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="City",
    aggfunc=lambda x: x.max() - x.min()
)
# Out:
#            Sales
# City
# Montreal       0
# Toronto       70
# Vancouver     40

# %% [markdown]
# 🟦 10. Pivot Table Returning Percentages

# %%
table = pd.pivot_table(
    df,
    values="Sales",
    index="City",
    columns="Month",
    aggfunc="sum"
)

table.div(table.sum(axis=1), axis=0) * 100
# Out:
# Month             Feb        Jan
# City
# Montreal   100.000000        NaN
# Toronto     42.857143  57.142857
# Vancouver   35.714286  64.285714

# %% [markdown]
# ## 🟦 Summary
#
# You have fully covered 7.1 Pivot Tables with pivot_table()
#
# This includes:
#
# ✔ Basic pivot tables
#
# ✔ Multi-level pivoting
#
# ✔ Multiple aggregations
#
# ✔ Handling missing values
#
# ✔ Custom functions
#
# ✔ Totals and percentages
