# %% [markdown]
# 🟦 1. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# 🟦 2. Sample Long-Format DataFrame

# %%
df = pd.DataFrame({
    "City": ["Toronto", "Toronto", "Vancouver", "Vancouver", "Montreal", "Montreal"],
    "Month": ["Jan", "Feb", "Jan", "Feb", "Jan", "Feb"],
    "Sales": [120, 150, 90, 100, 80, 110]
})

df
# Out:
#         City Month  Sales
# 0    Toronto   Jan    120
# 1    Toronto   Feb    150
# 2  Vancouver   Jan     90
# 3  Vancouver   Feb    100
# 4   Montreal   Jan     80
# 5   Montreal   Feb    110

# %% [markdown]
# 🟦 3. Basic pivot() — Long → Wide

# %%
df_wide = df.pivot(index="City", columns="Month", values="Sales")
df_wide
# Out:
# Month      Feb  Jan
# City
# Montreal   110   80
# Toronto    150  120
# Vancouver  100   90

# %% [markdown]
# 🟦 4. Handling Duplicates (Why pivot() Can Fail)

# %%
df_dup = pd.DataFrame({
    "City": ["Toronto", "Toronto", "Toronto"],
    "Month": ["Jan", "Jan", "Feb"],
    "Sales": [120, 125, 150]
})

# ❌ This will raise a ValueError
df_dup.pivot(index="City", columns="Month", values="Sales")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       1 df_dup = pd.DataFrame({
#       2     "City": ["Toronto", "Toronto", "Toronto"],
#       3     "Month": ["Jan", "Jan", "Feb"],
#       4     "Sales": [120, 125, 150]
#       5 })
#       7 # ❌ This will raise a ValueError
# ----> 8 df_dup.pivot(index="City", columns="Month", values="Sales")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     567 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     568 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569 # "Hashable"
# --> 570 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     571 result.index.names = [
#     572     name if name is not lib.no_default else None for name in result.index.names
#     573 ]
#     575 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4634, in Series.unstack(self, level, fill_value, sort)
#    4589 """
#    4590 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4591
#    (...)
#    4630 b    2    4
#    4631 """
#    4632 from pandas.core.reshape.reshape import unstack
# -> 4634 return unstack(self, level, fill_value, sort)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# ✔ To handle duplicates → use pivot_table() instead:
pd.pivot_table(df_dup, index="City", columns="Month", values="Sales", aggfunc="mean")
# Out:
# Month      Feb    Jan
# City
# Toronto  150.0  122.5

# %% [markdown]
# 🟦 5. Multiple Value Columns

# %%
df2 = pd.DataFrame({
    "City": ["Toronto", "Toronto", "Vancouver", "Vancouver"],
    "Month": ["Jan", "Feb", "Jan", "Feb"],
    "Sales": [120, 150, 90, 100],
    "Units": [10, 12, 8, 9]
})

df2.pivot(index="City", columns="Month")
# Out:
#           Sales      Units
# Month       Feb  Jan   Feb Jan
# City
# Toronto     150  120    12  10
# Vancouver   100   90     9   8

# %% [markdown]
# 🟦 6. Resetting Column Names

# %%
df_flat = df2.pivot(index="City", columns="Month")
df_flat.columns = ['_'.join(col).strip() for col in df_flat.columns.values]
df_flat.reset_index(inplace=True)
df_flat
# Out:
#         City  Sales_Feb  Sales_Jan  Units_Feb  Units_Jan
# 0    Toronto        150        120         12         10
# 1  Vancouver        100         90          9          8

# %%
ridership = pd.DataFrame({
    "Route": [10, 10, 20, 20],
    "Day": ["Weekday", "Weekend", "Weekday", "Weekend"],
    "Ridership": [5000, 3000, 4500, 2500]
})

ridership_wide = ridership.pivot(index="Route", columns="Day", values="Ridership")
ridership_wide
# Out:
# Day    Weekday  Weekend
# Route
# 10        5000     3000
# 20        4500     2500

# %% [markdown]
# 🟦 7. Flattening Columns After Pivot

# %%
ridership_wide.columns.name = None
ridership_wide.reset_index(inplace=True)
ridership_wide
# Out:
#    Route  Weekday  Weekend
# 0     10     5000     3000
# 1     20     4500     2500

# %% [markdown]
# ## 🟦 Summary
#
# You learned how to:
#
# ✔ Convert long → wide format using pivot()
#
# ✔ Understand when to use pivot() vs pivot_table()
#
# ✔ Handle duplicates safely using pivot_table()
#
# ✔ Pivot multiple value columns and flatten the result
