# %% [markdown]
# 🟦 1. Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 🟦 2. Create Sample Messy Dataset

# %%
data = {
    "id": ["1", "2", "3", "4"],
    "age": ["25", "30", "unknown", "40"],
    "salary": ["70000", "80000", "85000.5", "not available"],
    "hire_date": ["2021-01-05", "2020/03/12", "invalid_date", "2019-08-20"],
    "active": ["True", "False", "True", "False"]
}

df = pd.DataFrame(data)
df
# Out:
#   id      age         salary     hire_date active
# 0  1       25          70000    2021-01-05   True
# 1  2       30          80000    2020/03/12  False
# 2  3  unknown        85000.5  invalid_date   True
# 3  4       40  not available    2019-08-20  False

# %% [markdown]
# 🟦 3. View Current Data Types

# %%
df.dtypes
# Out:
# id           object
# age          object
# salary       object
# hire_date    object
# active       object
# dtype: object

# %% [markdown]
# 🟦 4. Convert Numeric Columns using astype()

# %%
df["id"] = df["id"].astype(int)
df["id"].dtype
# Out:
# dtype('int64')

# %%
# ❗ This fails because "unknown" is not numeric.
df["age"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # ❗ This fails because "unknown" is not numeric.
# ----> 2 df["age"].astype(int)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
# ...

# %% [markdown]
# 🟦 5. Safe Numeric Conversion using pd.to_numeric()

# %%
#Now invalid values become NaN

df["age"] = pd.to_numeric(df["age"], errors="coerce")
df["salary"] = pd.to_numeric(df["salary"], errors="coerce")

df
# Out:
#    id   age   salary     hire_date active
# 0   1  25.0  70000.0    2021-01-05   True
# 1   2  30.0  80000.0    2020/03/12  False
# 2   3   NaN  85000.5  invalid_date   True
# 3   4  40.0      NaN    2019-08-20  False

# %%
df.dtypes
# Out:
# id             int64
# age          float64
# salary       float64
# hire_date     object
# active        object
# dtype: object

# %% [markdown]
# 🟦 6. Convert Date Columns using pd.to_datetime()

# %%
df["hire_date"] = pd.to_datetime(df["hire_date"], errors="coerce")
df
# Out:
#    id   age   salary  hire_date active
# 0   1  25.0  70000.0 2021-01-05   True
# 1   2  30.0  80000.0        NaT  False
# 2   3   NaN  85000.5        NaT   True
# 3   4  40.0      NaN 2019-08-20  False

# %%
df.dtypes
# Out:
# id                    int64
# age                 float64
# salary              float64
# hire_date    datetime64[ns]
# active               object
# dtype: object

# %% [markdown]
# 🟦 7. Convert Boolean-like Column

# %%
df["active"] = df["active"].map({"True": True, "False": False})
df
# Out:
#    id   age   salary  hire_date  active
# 0   1  25.0  70000.0 2021-01-05    True
# 1   2  30.0  80000.0        NaT   False
# 2   3   NaN  85000.5        NaT    True
# 3   4  40.0      NaN 2019-08-20   False

# %%
df.dtypes
# Out:
# id                    int64
# age                 float64
# salary              float64
# hire_date    datetime64[ns]
# active                 bool
# dtype: object

# %%
df = df.astype({
    "id": int,
    "active": bool
})

df.dtypes
# Out:
# id                    int64
# age                 float64
# salary              float64
# hire_date    datetime64[ns]
# active                 bool
# dtype: object

# %% [markdown]
# 🟦 8. Using convert_dtypes() (Modern Pandas)

# %%
df_auto = df.convert_dtypes()
df_auto.dtypes
# Out:
# id                    Int64
# age                   Int64
# salary              Float64
# hire_date    datetime64[ns]
# active              boolean
# dtype: object

# %%
print("Original dtypes:\n", df.dtypes)
print("\nOptimized dtypes:\n", df_auto.dtypes)
# Out:
# Original dtypes:
#  id                    int64
# age                 float64
# salary              float64
# hire_date    datetime64[ns]
# active                 bool
# dtype: object
#
# Optimized dtypes:
#  id                    Int64
# age                   Int64
# salary              Float64
# hire_date    datetime64[ns]
# active              boolean
# dtype: object

# %% [markdown]
# ## ✅ Summary — Changing Data Types
#
# In this subsection, you learned how to:
#
# ✔ View column data types using `dtypes`
# ✔ Convert numeric columns using `astype()` and `pd.to_numeric()`
# ✔ Safely handle invalid values using `errors="coerce"`
# ✔ Convert date columns using `pd.to_datetime()`
# ✔ Convert string booleans into real boolean types
# ✔ Convert multiple columns at once
# ✔ Use `convert_dtypes()` for smart automatic conversion
# ✔ Identify failed conversions using `NaN` and `NaT`
