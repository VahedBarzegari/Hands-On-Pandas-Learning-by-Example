# %% [markdown]
# In this subsection, you will learn how to stack DataFrames vertically and horizontally, handle different column structures, ignore indexes, and concatenate inside loops—an essential pattern in real-world workflows.

# %% [markdown]
# 🟦 1. Import Library

# %%
import pandas as pd

# %% [markdown]
# 🟦 2. Create Sample DataFrames

# %%
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["Alice", "Bob", "Charlie"]
})

df2 = pd.DataFrame({
    "id": [4, 5],
    "name": ["Diana", "Evan"]
})
df1, df2
# Out:
# (   id     name
#  0   1    Alice
#  1   2      Bob
#  2   3  Charlie,
#     id   name
#  0   4  Diana
#  1   5   Evan)

# %% [markdown]
# 🟦 3. Vertical Concatenation (Stack Rows)

# %%
vertical = pd.concat([df1, df2])
vertical
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 0   4    Diana
# 1   5     Evan

# %% [markdown]
# 🟦 4. Vertical Concatenation with ignore_index=True

# %%
vertical_ignore = pd.concat([df1, df2], ignore_index=True)
vertical_ignore
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    Diana
# 4   5     Evan

# %% [markdown]
# 🟦 5. Horizontal Concatenation (Side-by-Side)

# %%
left = pd.DataFrame({"A": [1, 2, 3]})
right = pd.DataFrame({"B": ["x", "y", "z"]})

horizontal = pd.concat([left, right], axis=1)
horizontal
# Out:
#    A  B
# 0  1  x
# 1  2  y
# 2  3  z

# %% [markdown]
# 🟦 6. Concatenation with Different Columns

# %%
df3 = pd.DataFrame({
    "id": [6, 7],
    "age": [30, 25]
})

concat_diff = pd.concat([df1, df3], ignore_index=True)
concat_diff
# Out:
#    id     name   age
# 0   1    Alice   NaN
# 1   2      Bob   NaN
# 2   3  Charlie   NaN
# 3   6      NaN  30.0
# 4   7      NaN  25.0

# %% [markdown]
# 🟦 7. Concatenating with Alignment on Index

# %%
df_a = pd.DataFrame({"value1": [10, 20, 30]}, index=["a", "b", "c"])
df_b = pd.DataFrame({"value2": [100, 200]}, index=["a", "c"])

concat_align = pd.concat([df_a, df_b], axis=1)
concat_align
# Out:
#    value1  value2
# a      10   100.0
# b      20     NaN
# c      30   200.0

# %% [markdown]
# 🟦 8. Concatenation in a Loop (Real-World Use Case)

# %%
dataframes = []

for month in ["Jan", "Feb", "Mar"]:
    df = pd.DataFrame({
        "month": [month] * 2,
        "sales": [100, 150]
    })
    dataframes.append(df)

yearly_sales = pd.concat(dataframes, ignore_index=True)
yearly_sales
# Out:
#   month  sales
# 0   Jan    100
# 1   Jan    150
# 2   Feb    100
# 3   Feb    150
# 4   Mar    100
# 5   Mar    150

# %% [markdown]
# ## 🟦 Summary
#
# In this subsection you learned how to:
#
# ✔️ Stack DataFrames vertically or horizontally
#
# ✔️ Combine DataFrames with different columns
#
# ✔️ Control index behavior using ignore_index
#
# ✔️ Align data by index when concatenating along columns
#
# ✔️ Concatenate inside loops — a common real-world workflow
